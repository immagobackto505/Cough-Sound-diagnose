# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras #type: ignore
import tensorflow as tf #type: ignore
import random

# %%
DATA_PATH = r'C:\Users\kikin\OneDrive\Documents\GitHub\Cough-Sound-diagnose\dataset_full.json'
def load_data(data_path):
    with open(data_path, 'r') as f:
        data = json.load(f)
    
    X = np.array(data['mfcc'])
    y = np.array(data['labels'])
    return X, y

# %%
def prepare_datasets(test_size, validation_size):
    # load data
    X, y = load_data(DATA_PATH)
    
    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    
    # create train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    #3d array 
    print(X_train.shape, X_validation.shape, X_test.shape)
    X_train = X_train[..., np.newaxis] 
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    print(X_train.shape, X_validation.shape, X_test.shape)
    
    return X_train, X_validation, X_test, y_train, y_validation, y_test

prepare_datasets(0.25, 0.2)
# Out:
# (262, 87, 13) (66, 87, 13) (110, 87, 13)
# (262, 87, 13, 1) (66, 87, 13, 1) (110, 87, 13, 1)
# (array([[[[-645.68463135],
#           [ 101.17344666],
#           [  10.87486839],
#           ...,
#           [ -20.49400711],
#           [ -11.90348816],
#           [  13.16423607]],
#
#          [[-663.75860596],
#           [  86.25136566],
#           [   8.57172203],
#           ...,
#           [ -22.82989883],
#           [ -10.51887321],
#           [  21.11142731]],
#
#          [[-680.73443604],
#           [  65.03741455],
#           [  -4.63640594],
#           ...,
#           [  -6.51627922],
#           [  -1.68052101],
#           [  26.92273712]],
#
#          ...,
#
#          [[-759.69543457],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-759.69543457],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-759.69543457],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]]],
#
#
#         [[[-215.14912415],
#           [ 108.94530487],
#           [ -89.51139832],
#           ...,
#           [  11.08337402],
#           [   2.28947401],
#           [  -2.77903509]],
#
#          [[-414.84814453],
#           [ -13.53192711],
#           [-185.27307129],
#           ...,
#           [  24.12783241],
#           [ -12.70915222],
#           [  -8.43706608]],
#
#          [[-410.89013672],
#           [ -21.40740967],
#           [-180.73135376],
#           ...,
#           [  34.77261353],
#           [  -8.44662094],
#           [ -21.0793457 ]],
#
#          ...,
#
#          [[-475.23553467],
#           [ 181.54980469],
#           [  62.40817261],
#           ...,
#           [ -22.90044403],
#           [ -40.83841705],
#           [ -58.00284958]],
#
#          [[-444.1257019 ],
#           [ 189.57171631],
#           [  32.59825897],
#           ...,
#           [ -15.98972797],
#           [ -25.79174805],
#           [ -50.22371674]],
#
#          [[-256.34683228],
#           [ 152.19271851],
#           [  21.81261063],
#           ...,
#           [  -1.44214225],
#           [ -11.82165337],
#           [ -21.42811584]]],
#
#
#         [[[-731.09136963],
#           [  34.39050674],
#           [  29.86408615],
#           ...,
#           [ -19.70866013],
#           [ -16.58636093],
#           [  -9.22255325]],
#
#          [[-715.36993408],
#           [  45.03491211],
#           [  45.25041199],
#           ...,
#           [ -11.59963226],
#           [ -12.64945793],
#           [  -6.69035625]],
#
#          [[-702.2399292 ],
#           [  56.66671753],
#           [  53.93630981],
#           ...,
#           [ -13.6339798 ],
#           [ -16.25662804],
#           [  -9.01178741]],
#
#          ...,
#
#          [[-761.67321777],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-761.67321777],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-761.67321777],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]]],
#
#
#         ...,
#
#
#         [[[-485.7930603 ],
#           [ 136.25802612],
#           [ -52.04667664],
#           ...,
#           [  -1.8797884 ],
#           [ -10.69133663],
#           [ -11.80985546]],
#
#          [[-457.09326172],
#           [ 146.890625  ],
#           [ -53.76976013],
#           ...,
#           [   6.91179419],
#           [ -15.83329773],
#           [ -12.33616638]],
#
#          [[-404.98471069],
#           [ 150.14875793],
#           [ -66.49486542],
#           ...,
#           [  -9.64250374],
#           [ -23.07801628],
#           [  -1.56757116]],
#
#          ...,
#
#          [[-782.0760498 ],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-782.0760498 ],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-782.0760498 ],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]]],
#
#
#         [[[-700.42907715],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-700.42907715],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-700.42907715],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          ...,
#
#          [[-700.42907715],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-700.42907715],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-700.42907715],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]]],
#
#
#         [[[-680.72174072],
#           [  54.21598053],
#           [  40.70682526],
#           ...,
#           [ -18.27899361],
#           [ -18.46807098],
#           [ -17.43839073]],
#
#          [[-689.32696533],
#           [  44.23007965],
#           [  39.667202  ],
#           ...,
#           [ -17.8053875 ],
#           [ -17.70673752],
#           [ -15.14638901]],
#
#          [[-681.0012207 ],
#           [  55.09209442],
#           [  47.67533875],
#           ...,
#           [ -16.74414825],
#           [ -14.64566803],
#           [ -11.31465054]],
#
#          ...,
#
#          [[-722.70947266],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-722.70947266],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]],
#
#          [[-722.70947266],
#           [   0.        ],
#           [   0.        ],
#           ...,
#           [   0.        ],
#           [   0.        ],
#           [   0.        ]]]]),
#  array([[[[-7.27694275e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.27694275e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.27694275e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          ...,
#
#          [[-2.73593750e+02],
#           [ 1.76730209e+02],
#           [-2.49758358e+01],
#           ...,
#           [-9.29595566e+00],
#           [-2.62775173e+01],
#           [-1.74622273e+00]],
#
#          [[-3.44032471e+02],
#           [ 1.92670822e+02],
#           [ 7.51601601e+00],
#           ...,
#           [-1.44347343e+01],
#           [-1.41073866e+01],
#           [-3.11378789e+00]],
#
#          [[-3.27145447e+02],
#           [ 1.59648117e+02],
#           [ 5.86472092e+01],
#           ...,
#           [-1.09060745e+01],
#           [-7.53225946e+00],
#           [-1.96352768e+01]]],
#
#
#         [[[-7.11235657e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.11235657e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.11235657e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          ...,
#
#          [[-3.97821838e+02],
#           [ 1.72818329e+02],
#           [-4.82523651e+01],
#           ...,
#           [ 8.90388680e+00],
#           [-4.28120899e+00],
#           [-1.79342575e+01]],
#
#          [[-4.84850739e+02],
#           [ 1.30317963e+02],
#           [-3.72535553e+01],
#           ...,
#           [ 3.27133484e+01],
#           [ 8.82873821e+00],
#           [-9.33610725e+00]],
#
#          [[-5.47398682e+02],
#           [ 1.26771210e+02],
#           [-5.17239451e-01],
#           ...,
#           [ 1.76544800e+01],
#           [ 9.43818951e+00],
#           [ 7.01857901e+00]]],
#
#
#         [[[-7.59346069e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.59346069e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.59346069e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          ...,
#
#          [[-7.59346069e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.52322571e+02],
#           [ 5.37601519e+00],
#           [-3.90629578e+00],
#           ...,
#           [-3.36519361e+00],
#           [ 1.43629706e+00],
#           [ 3.91566873e+00]],
#
#          [[-7.46091370e+02],
#           [ 1.16569777e+01],
#           [-3.72996831e+00],
#           ...,
#           [-3.53594065e+00],
#           [-3.79330730e+00],
#           [-2.38634062e+00]]],
#
#
#         ...,
#
#
#         [[[-6.99485474e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-6.99485474e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-6.99485474e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          ...,
#
#          [[-6.99485474e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-6.99485474e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-6.99485474e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]]],
#
#
#         [[[-3.47470123e+02],
#           [ 6.47755432e+01],
#           [-2.18266144e+01],
#           ...,
#           [ 7.32712078e+00],
#           [ 1.37008142e+01],
#           [-4.87520647e+00]],
#
#          [[-3.68465118e+02],
#           [ 7.26621094e+01],
#           [-1.94618301e+01],
#           ...,
#           [ 5.49281788e+00],
#           [ 4.71839828e+01],
#           [ 4.79175949e+00]],
#
#          [[-3.92641449e+02],
#           [ 7.50930481e+01],
#           [ 3.45339513e+00],
#           ...,
#           [ 2.83893538e+00],
#           [ 4.70062103e+01],
#           [ 5.99279976e+00]],
#
#          ...,
#
#          [[-7.25818542e+02],
#           [-2.41987705e+00],
#           [-9.19337845e+00],
#           ...,
#           [ 7.10029030e+00],
#           [ 5.09361982e+00],
#           [-9.35306549e+00]],
#
#          [[-7.25911926e+02],
#           [-2.38240504e+00],
#           [-8.82015991e+00],
#           ...,
#           [ 7.60442019e+00],
#           [ 3.97215343e+00],
#           [-9.15278149e+00]],
#
#          [[-7.19615173e+02],
#           [-4.56048632e+00],
#           [-1.68054638e+01],
#           ...,
#           [ 1.18835278e+01],
#           [ 7.21492386e+00],
#           [-1.42904301e+01]]],
#
#
#         [[[-8.02103882e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-8.01987671e+02],
#           [ 1.64248675e-01],
#           [ 1.63914710e-01],
#           ...,
#           [ 1.53346747e-01],
#           [ 1.51065588e-01],
#           [ 1.48579717e-01]],
#
#          [[-8.02007202e+02],
#           [ 1.36635631e-01],
#           [ 1.36355907e-01],
#           ...,
#           [ 1.27564847e-01],
#           [ 1.25668854e-01],
#           [ 1.23599328e-01]],
#
#          ...,
#
#          [[-4.27844727e+02],
#           [ 5.56252975e+01],
#           [-1.13119270e+02],
#           ...,
#           [-4.47318039e+01],
#           [-4.21074257e+01],
#           [ 3.08494530e+01]],
#
#          [[-4.43515808e+02],
#           [ 4.33730011e+01],
#           [-1.22875168e+02],
#           ...,
#           [-3.91383362e+01],
#           [-2.63341274e+01],
#           [ 5.08938675e+01]],
#
#          [[-3.73305389e+02],
#           [ 9.07801208e+01],
#           [-4.70519028e+01],
#           ...,
#           [-9.26205635e+00],
#           [-1.58610172e+01],
#           [ 2.00124645e+01]]]]),
#  array([[[[-7.13744507e+02],
#           [ 6.69512405e+01],
#           [ 5.52326164e+01],
#           ...,
#           [-5.70353222e+00],
#           [-1.12968473e+01],
#           [-1.05373669e+01]],
#
#          [[-7.08594360e+02],
#           [ 7.19930573e+01],
#           [ 6.41920471e+01],
#           ...,
#           [-1.03221493e+01],
#           [-1.97592583e+01],
#           [-1.43147392e+01]],
#
#          [[-7.10471069e+02],
#           [ 6.76787109e+01],
#           [ 5.94769173e+01],
#           ...,
#           [-1.15487146e+01],
#           [-2.15716782e+01],
#           [-1.35473728e+01]],
#
#          ...,
#
#          [[-7.65937866e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.65937866e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.65937866e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]]],
#
#
#         [[[-6.49526001e+02],
#           [ 8.64583740e+01],
#           [ 3.97551842e+01],
#           ...,
#           [-4.77190638e+00],
#           [ 6.02531910e+00],
#           [ 2.17671895e+00]],
#
#          [[-6.54634155e+02],
#           [ 8.06020889e+01],
#           [ 3.86530685e+01],
#           ...,
#           [-3.20375633e+01],
#           [-1.54722214e+01],
#           [-5.79517889e+00]],
#
#          [[-6.46944641e+02],
#           [ 8.68033371e+01],
#           [ 4.22797241e+01],
#           ...,
#           [-3.03446808e+01],
#           [-2.02381344e+01],
#           [-1.32019386e+01]],
#
#          ...,
#
#          [[-5.66558411e+02],
#           [-4.23462677e+00],
#           [-3.67403412e+01],
#           ...,
#           [-2.00972595e+01],
#           [-1.39307575e+01],
#           [ 1.37730618e+01]],
#
#          [[-6.04112427e+02],
#           [ 3.50629449e+00],
#           [-3.63722496e+01],
#           ...,
#           [-2.59858322e+01],
#           [-2.20931644e+01],
#           [ 1.24876709e+01]],
#
#          [[-5.61766541e+02],
#           [ 5.14838638e+01],
#           [-4.67178726e+01],
#           ...,
#           [-1.72050209e+01],
#           [-9.66705132e+00],
#           [-5.84845638e+00]]],
#
#
#         [[[-7.71375977e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.71375977e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.71375977e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          ...,
#
#          [[-7.71375977e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.68459473e+02],
#           [-3.55436087e+00],
#           [ 2.00207615e+00],
#           ...,
#           [ 2.31356525e+00],
#           [-3.67531896e+00],
#           [ 4.01479864e+00]],
#
#          [[-7.69163696e+02],
#           [-2.71040154e+00],
#           [ 1.56802058e+00],
#           ...,
#           [ 1.51874995e+00],
#           [-2.64804840e+00],
#           [ 3.06469774e+00]]],
#
#
#         ...,
#
#
#         [[[-7.22223267e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.22223267e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.22223267e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          ...,
#
#          [[-7.09930603e+02],
#           [ 1.73349152e+01],
#           [ 1.71869926e+01],
#           ...,
#           [ 1.29370975e+01],
#           [ 1.21236439e+01],
#           [ 1.12765722e+01]],
#
#          [[-7.17614136e+02],
#           [ 6.50151634e+00],
#           [ 6.45135498e+00],
#           ...,
#           [ 4.95369625e+00],
#           [ 4.65278101e+00],
#           [ 4.33368826e+00]],
#
#          [[-7.21713928e+02],
#           [ 7.18828797e-01],
#           [ 7.14452744e-01],
#           ...,
#           [ 5.82735777e-01],
#           [ 5.55985451e-01],
#           [ 5.27496219e-01]]],
#
#
#         [[[-7.08953064e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.08953064e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          [[-7.08953064e+02],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           ...,
#           [ 0.00000000e+00],
#           [ 0.00000000e+00],
#           [ 0.00000000e+00]],
#
#          ...,
#
#          [[-6.81823914e+02],
#           [-2.44242897e+01],
#           [-4.95149755e+00],
#           ...,
#           [-1.44581041e+01],
#           [-5.55404568e+00],
#           [ 1.84271679e+01]],
#
#          [[-6.80860840e+02],
#           [-2.60161514e+01],
#           [-3.15431786e+00],
#           ...,
#           [-1.71360455e+01],
#           [-5.02633524e+00],
#           [ 2.15298767e+01]],
#
#          [[-6.75818726e+02],
#           [-3.08930550e+01],
#           [-3.06001043e+00],
#           ...,
#           [-1.72479095e+01],
#           [-3.53477693e+00],
#           [ 1.86615944e+01]]],
#
#
#         [[[-5.71028625e+02],
#           [ 3.10083046e+01],
#           [-8.09351444e+00],
#           ...,
#           [-4.15074348e+00],
#           [ 1.73193321e+01],
#           [ 1.93202627e+00]],
#
#          [[-6.03978821e+02],
#           [ 2.42718182e+01],
#           [ 1.23915024e+01],
#           ...,
#           [ 4.57457447e+00],
#           [ 2.59931240e+01],
#           [-9.74162960e+00]],
#
#          [[-5.87808533e+02],
#           [ 3.93442192e+01],
#           [ 1.24810181e+01],
#           ...,
#           [-1.28851271e+00],
#           [ 2.85896645e+01],
#           [-6.67572117e+00]],
#
#          ...,
#
#          [[-6.79407654e+02],
#           [ 1.68332748e+01],
#           [ 1.15766544e+01],
#           ...,
#           [-3.62896252e+00],
#           [ 3.07201385e+00],
#           [ 8.62938690e+00]],
#
#          [[-6.78623657e+02],
#           [ 1.79498711e+01],
#           [ 1.26837006e+01],
#           ...,
#           [-6.02396202e+00],
#           [ 1.37834668e+00],
#           [ 8.09673309e+00]],
#
#          [[-6.71260620e+02],
#           [ 2.71517944e+01],
#           [ 1.86517735e+01],
#           ...,
#           [-2.11715937e+00],
#           [ 5.41549873e+00],
#           [ 1.07409000e+01]]]]),
#  array([0, 1, 0, 0, 2, 3, 2, 1, 2, 1, 1, 3, 3, 0, 3, 3, 0, 3, 1, 2, 2, 2,
#         0, 1, 1, 2, 2, 1, 3, 3, 1, 3, 3, 1, 0, 1, 1, 1, 2, 3, 0, 3, 0, 0,
#         2, 2, 1, 1, 3, 3, 3, 2, 2, 3, 1, 0, 2, 1, 3, 1, 0, 3, 1, 2, 2, 2,
#         0, 1, 2, 2, 1, 0, 2, 1, 2, 0, 1, 2, 3, 1, 0, 2, 2, 2, 1, 0, 2, 3,
#         1, 2, 3, 2, 2, 1, 2, 2, 0, 3, 1, 2, 0, 0, 2, 0, 2, 0, 2, 2, 3, 2,
#         2, 3, 0, 0, 0, 1, 3, 1, 1, 1, 0, 0, 1, 1, 2, 1, 1, 1, 3, 3, 2, 2,
#         0, 1, 1, 3, 3, 0, 0, 1, 1, 3, 1, 3, 0, 0, 3, 2, 2, 3, 3, 2, 2, 2,
#         1, 0, 1, 0, 3, 0, 1, 1, 3, 1, 2, 0, 0, 0, 2, 1, 3, 2, 0, 0, 2, 2,
#         0, 1, 1, 2, 1, 3, 0, 3, 2, 0, 0, 1, 3, 1, 0, 0, 2, 2, 3, 1, 3, 0,
#         0, 2, 2, 2, 2, 2, 2, 1, 0, 3, 3, 0, 2, 0, 2, 0, 0, 0, 2, 1, 2, 0,
#         3, 0, 0, 2, 1, 1, 1, 0, 0, 1, 1, 2, 2, 3, 0, 1, 3, 2, 2, 3, 3, 0,
#         2, 0, 3, 3, 0, 3, 1, 3, 1, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3, 0]),
#  array([2, 2, 0, 2, 3, 1, 0, 3, 0, 2, 1, 3, 2, 0, 2, 1, 3, 1, 0, 1, 0, 1,
#         2, 2, 0, 0, 3, 2, 2, 0, 3, 3, 1, 2, 0, 1, 2, 2, 0, 3, 0, 2, 2, 2,
#         1, 1, 0, 1, 2, 3, 1, 3, 0, 0, 1, 3, 0, 3, 2, 1, 1, 0, 3, 1, 0, 2]),
#  array([3, 0, 1, 0, 1, 3, 0, 1, 2, 2, 3, 2, 0, 3, 1, 3, 1, 2, 2, 1, 2, 2,
#         1, 0, 2, 0, 2, 1, 2, 1, 0, 0, 2, 0, 1, 2, 2, 0, 1, 1, 1, 1, 3, 3,
#         1, 1, 1, 1, 0, 0, 0, 1, 0, 0, 1, 1, 1, 2, 3, 3, 2, 0, 2, 1, 3, 0,
#         3, 2, 1, 3, 2, 0, 0, 3, 1, 1, 1, 2, 2, 1, 1, 0, 3, 1, 2, 1, 0, 2,
#         1, 0, 0, 2, 2, 1, 2, 3, 3, 1, 2, 3, 2, 2, 0, 3, 1, 3, 0, 2, 1, 0]))

# %%
def build_model(input_shape):
   #create model
    model = tf.keras.Sequential()
    
    #1st conv layer
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    
    #2nd conv layer
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    
    #3rd conv layer
    model.add(tf.keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(tf.keras.layers.BatchNormalization())
    
    #flatten the output and feed it into dense layer
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.3))
    
    #output layer
    model.add(tf.keras.layers.Dense(4, activation='softmax'))
    
    return model

# %%
def predict(model, X, y):
    X = X[np.newaxis, ...]
    prediction = model.predict(X)
    predicted_index = np.argmax(prediction, axis=1)
    print(f'Expected index: {y}, Predicted index: {predicted_index}')

# %%
if __name__ == '__main__':
   #create train, validation and test sets
   X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25,0.2) #(0.25,0.2) 25% test, 20% validation

   #build the CNN net
   input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
   model = build_model(input_shape)

   #compile the network
   optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
   model.compile(optimizer=optimizer,
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

   #train the CNN
   model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)
   model.summary()

   #evaluate the CNN on the test set
   test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
   print(f'Accuracy on test set is: {test_accuracy}')

   #make predictions on a sample
# Out:
# (262, 87, 13) (66, 87, 13) (110, 87, 13)
# (262, 87, 13, 1) (66, 87, 13, 1) (110, 87, 13, 1)
# Epoch 1/30
# c:\Users\kikin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.1864 - loss: 1.9074 - val_accuracy: 0.2879 - val_loss: 2.9853
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2811 - loss: 1.6961 - val_accuracy: 0.2879 - val_loss: 2.3522
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2792 - loss: 1.6058 - val_accuracy: 0.2879 - val_loss: 2.0748
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3414 - loss: 1.4808 - val_accuracy: 0.2879 - val_loss: 1.8728
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3291 - loss: 1.3936 - val_accuracy: 0.2879 - val_loss: 1.7286
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4125 - loss: 1.2480 - val_accuracy: 0.2879 - val_loss: 1.6234
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4344 - loss: 1.2096 - val_accuracy: 0.2879 - val_loss: 1.5593
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5099 - loss: 1.0861 - val_accuracy: 0.3030 - val_loss: 1.5092
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4952 - loss: 1.0931 - val_accuracy: 0.2727 - val_loss: 1.4570
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4921 - loss: 1.0104 - val_accuracy: 0.2727 - val_loss: 1.4128
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5166 - loss: 1.0252 - val_accuracy: 0.2727 - val_loss: 1.3786
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5375 - loss: 0.9481 - val_accuracy: 0.2727 - val_loss: 1.3562
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5577 - loss: 0.9920 - val_accuracy: 0.2727 - val_loss: 1.3419
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6077 - loss: 0.8775 - val_accuracy: 0.3030 - val_loss: 1.3255
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5604 - loss: 0.9042 - val_accuracy: 0.3030 - val_loss: 1.3119
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5991 - loss: 0.9117 - val_accuracy: 0.3182 - val_loss: 1.2926
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5967 - loss: 0.8590 - val_accuracy: 0.3030 - val_loss: 1.2771
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6176 - loss: 0.8109 - val_accuracy: 0.3333 - val_loss: 1.2677
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6934 - loss: 0.7874 - val_accuracy: 0.3030 - val_loss: 1.2583
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7050 - loss: 0.7551 - val_accuracy: 0.3485 - val_loss: 1.2537
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6896 - loss: 0.7784 - val_accuracy: 0.3636 - val_loss: 1.2498
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6954 - loss: 0.7364 - val_accuracy: 0.3636 - val_loss: 1.2425
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7240 - loss: 0.7197 - val_accuracy: 0.3788 - val_loss: 1.2388
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6995 - loss: 0.7038 - val_accuracy: 0.3788 - val_loss: 1.2367
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7116 - loss: 0.6943 - val_accuracy: 0.3788 - val_loss: 1.2395
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7123 - loss: 0.6867 - val_accuracy: 0.3636 - val_loss: 1.2407
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7310 - loss: 0.6662 - val_accuracy: 0.3485 - val_loss: 1.2403
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6914 - loss: 0.7029 - val_accuracy: 0.3636 - val_loss: 1.2356
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7954 - loss: 0.6189 - val_accuracy: 0.3788 - val_loss: 1.2366
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7610 - loss: 0.6256 - val_accuracy: 0.4091 - val_loss: 1.2390
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 85, 11, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 43, 6, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 43, 6, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 41, 4, 32)      │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 21, 2, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 21, 2, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 20, 1, 32)      │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 10, 1, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 10, 1, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 320)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        20,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,270 (407.31 KB)
#  Trainable params: 34,692 (135.52 KB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 69,386 (271.04 KB)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5203 - loss: 0.9667
# Accuracy on test set is: 0.5272727012634277

# %%
predict(model, X_test[random.randint(0, len(X_test) - 1)], y_test[random.randint(0, len(y_test) - 1)])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Expected index: 1, Predicted index: [3]

# %%
model.save('cough_classifier.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
